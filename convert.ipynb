# %%
import pandas as pd
import csv
import json

excel_data_fragment = pandas.read_excel('Response.xlsx', sheet_name='Sheet1')

json_str = excel_data_fragment.to_json()

print('Excel Sheet to JSON:\n', json_str)
# Out:
# Excel Sheet to JSON:
# ...

# %%
excel_data_fragment = pandas.read_excel('Response.xlsx', sheet_name='Sheet1')

# %%
excel_data_fragment.to_csv ("Test.csv", 
                  index = None,
                  header=True)

# %%
df = pd.read_csv (r'Test.csv')

# %%
df.to_json (r'response.json')

# %%
df
# Out:
#       No                               Anxiety  \
# 0    NaN                              Restless
# 1    1.0            What can I do to help you?
# 2    2.0                Let's listen to a song
# 3    3.0           How many hours do you work?
# 4    4.0  Are you happy with your current job?
# 5    5.0       Hope these images will help you
# 6    6.0                                   NaN
# 7    7.0                                   NaN
# 8    8.0                                   NaN
# 9    9.0                                   NaN
# 10  10.0                                   NaN
# 11  11.0                                   NaN
# 12  12.0                                   NaN
# 13  13.0                                   NaN
# 14  14.0                                   NaN
# 15  15.0                                   NaN
#
#                                            Unnamed: 2  \
# 0                                             Fatigue
# ...
